// %% [markdown]
// ---
// title: Java Console Games Tangibles
// description: Completing the Java Console Games Hacks.
// toc: True
// badges: False
// comments: True
// author: Tirth Thakkar
// categories: ['week01']
// type: tangibles
// courses: { compsci: {week: 1} }
// layout: notebook
// ---

// %%
import java.util.Scanner;
import java.util.Random;

public class RockPaperScissorsGame {
    private static final String DEFAULT = "\u001B[0m";  // Default Terminal Color

    public static void main(String[] args) {
        playRPS();
    }

    public static void playRPS() {
        Scanner sc = new Scanner(System.in);
        
        System.out.println("Rock Paper Scissors");
        System.out.println("Type 'r' for rock, 'p' for paper, or 's' for scissors");
        
        Random random = new Random();
        char[] choices = {'r', 'p', 's'};
        char userChoice = sc.nextLine().toLowerCase().charAt(0);
        char computerChoice = choices[random.nextInt(3)];
        
        // Game logic
        if (userChoice == computerChoice) {
            System.out.println("It's a tie!");
        } else if (
            (userChoice == 'r' && computerChoice == 's') ||
            (userChoice == 's' && computerChoice == 'p') ||
            (userChoice == 'p' && computerChoice == 'r')
        ) {
            System.out.println("You win!");
        } else {
            System.out.println("Computer wins!");
        }
        
        sc.close();
    }
}

// %%
import java.util.Scanner;

public class TicTacToeGame {
    public static void main(String[] args) {
        playTicTacToe();
    }

    public static void playTicTacToe() {
        Scanner sc = new Scanner(System.in);
        char[] board = {'1', '2', '3', '4', '5', '6', '7', '8', '9'};
        char currentPlayer = 'X';
        int moves = 0;
        boolean gameWon = false;

        System.out.println("Tic Tac Toe");
        System.out.println("Type the number of the square you want to place your piece in");
        displayBoard(board);

        while (moves < 9 && !gameWon) {
            System.out.println("Player " + currentPlayer + "'s turn");
            int move = sc.nextInt();

            if (move < 1 || move > 9 || board[move - 1] == 'X' || board[move - 1] == 'O') {
                System.out.println("Invalid move. Try again.");
                continue;
            }

            board[move - 1] = currentPlayer;
            moves++;
            displayBoard(board);

            // Check win conditions
            if (checkWin(board, currentPlayer)) {
                System.out.println("Player " + currentPlayer + " wins!");
                gameWon = true;
            }

            // Switch players
            currentPlayer = (currentPlayer == 'X') ? 'O' : 'X';
        }

        if (!gameWon) {
            System.out.println("It's a tie!");
        }

        sc.close();
    }

    private static void displayBoard(char[] board) {
        System.out.println(board[0] + " | " + board[1] + " | " + board[2]);
        System.out.println("---------");
        System.out.println(board[3] + " | " + board[4] + " | " + board[5]);
        System.out.println("---------");
        System.out.println(board[6] + " | " + board[7] + " | " + board[8]);
    }

    private static boolean checkWin(char[] board, char player) {
        // Check rows, columns, and diagonals for a win
        return ((board[0] == player && board[1] == player && board[2] == player) ||
                (board[3] == player && board[4] == player && board[5] == player) ||
                (board[6] == player && board[7] == player && board[8] == player) ||
                (board[0] == player && board[3] == player && board[6] == player) ||
                (board[1] == player && board[4] == player && board[7] == player) ||
                (board[2] == player && board[5] == player && board[8] == player) ||
                (board[0] == player && board[4] == player && board[8] == player) ||
                (board[2] == player && board[4] == player && board[6] == player));
    }
}

// %%
import java.util.Scanner;
import java.util.Random;

public class HigherLowerGame {
    public static void main(String[] args) {
        playHigherLower();
    }

    public static void playHigherLower() {
        Scanner sc = new Scanner(System.in);
        Random random = new Random();
        int targetNumber = random.nextInt(8) + 1;
        int remainingAttempts = 3;

        System.out.println("Higher or Lower");
        System.out.println("You have three guesses to guess the number I'm thinking of between 1-8.");

        while (remainingAttempts > 0) {
            System.out.print("Enter your guess: ");
            int userGuess = sc.nextInt();

            if (userGuess == targetNumber) {
                System.out.println("You win!");
                break;
            } else if (userGuess < targetNumber) {
                System.out.println("The number is higher.");
            } else {
                System.out.println("The number is lower.");
            }

            remainingAttempts--;
        }

        if (remainingAttempts == 0) {
            System.out.println("Game over. The correct number was " + targetNumber);
        }

        sc.close();
    }
}

// %%
import java.util.Scanner;

public class Menu {
    private static Scanner sc = new Scanner(System.in);

    public static void main(String[] args) {
        int wins = 0;

        while (true) {
            wins = displayMenu(wins);
            int choice = getUserChoice();

            switch (choice) {
                case 0:
                    System.out.println("Thank you for playing! You won " + wins + " game(s). Goodbye!");
                    return;
                case 1:
                    System.out.println("Let's play Rock Paper Scissors!");
                    boolean resultRPS = RockPaperScissors.play();
                    if (resultRPS) {
                        wins++;
                        System.out.println("You won the game! Your total wins: " + wins);
                    } else {
                        System.out.println("You lost the game. Your total wins: " + wins);
                    }
                    break;
                case 2:
                    System.out.println("Get ready for Higher or Lower!");
                    boolean resultHORL = HigherOrLower.play();
                    if (resultHORL) {
                        wins++;
                        System.out.println("You won the game! Your total wins: " + wins);
                    } else {
                        System.out.println("You lost the game. Your total wins: " + wins);
                    }
                    break;
                case 3:
                    System.out.println("Time for a game of Tic Tac Toe!");
                    boolean resultTTT = TicTacToe.play();
                    if (resultTTT) {
                        wins++;
                        System.out.println("You won the game! Your total wins: " + wins);
                    } else {
                        System.out.println("You lost the game. Your total wins: " + wins);
                    }
                    break;
                default:
                    System.out.println("Invalid choice, please select a valid option.");
            }
        }
    }

    public static int displayMenu(int wins) {
        System.out.println("___________________________");
        System.out.println("|~~~~~~~~~~~~~~~~~~~~~~~~~|");
        System.out.println("|          Menu!          |");
        System.out.println("|~~~~~~~~~~~~~~~~~~~~~~~~~|");
        System.out.println("| 0 - Exit                |");
        System.out.println("| 1 - Rock Paper Scissors |");
        System.out.println("| 2 - Higher or Lower     |");
        System.out.println("| 3 - Tic Tac Toe         |");
        System.out.println("|_________________________|");
        System.out.println("\nChoose an option.");
        System.out.println("Total Wins: " + wins);
        return wins;
    }

    public static int getUserChoice() {
        try {
            int choice = sc.nextInt();
            sc.nextLine(); // Consume the newline character
            return choice;
        } catch (Exception e) {
            sc.nextLine(); // Consume the invalid input
            System.out.println("Invalid input. Please enter a number.");
            return getUserChoice(); // Recursively get valid input
        }
    }
}
